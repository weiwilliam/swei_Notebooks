# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
npro = 162
naer = 15
nlev = 72
npro * naer * nlev
# Out:
# 174960

# %%
data0 = np.loadtxt('/glade/work/swei/projects/caliop_opr/JEDI-ACE/workdir/aeroconc_0.dat').ravel()
data1 = np.loadtxt('/glade/work/swei/projects/caliop_opr/JEDI-ACE/workdir/aeroconc_1.dat').ravel()
data0.shape, data1.shape
# Out:
# ((174960,), (174960,))

# %%
conc0 = data0.reshape(npro, naer, nlev)
conc1 = data1.reshape(npro, naer, nlev)

# %%
plt.imshow(conc0.sum(axis=1).T)

# %%
plt.imshow(conc1.sum(axis=1).T)
