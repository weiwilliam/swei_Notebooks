# %%
import xarray as xa

# %%
gval_path = '/glade/work/swei/Git/JEDI-METplus/output/aodobs_merra2/geovals/f00/pace_aod'
gval_file = 'geovals.pace_aod.2024110106_0000.nc4'

# %%
ds = xa.open_dataset(f'{gval_path}/{gval_file}')

# %%
ds
# Out:
# <xarray.Dataset> Size: 2GB
# Dimensions:                                             (nlocs: 262177,
#                                                          air_temperature_nval: 72,
#                                                          water_vapor_mixing_ratio_wrt_dry_air_nval: 72,
#                                                          relative_humidity_nval: 72,
#                                                          air_pressure_nval: 72,
#                                                          air_pressure_levels_nval: 73,
#                                                          ...
#                                                          mass_fraction_of_dust005_in_air_nval: 72,
#                                                          mass_fraction_of_sea_salt001_in_air_nval: 72,
#                                                          mass_fraction_of_sea_salt002_in_air_nval: 72,
# ...

# %%
ds.mass_fraction_of_sea_salt001_in_air.max()
# Out:
# <xarray.DataArray 'mass_fraction_of_sea_salt001_in_air' ()> Size: 8B
# array(1.9994166e-10)
