# %%
from PIL import Image, ImageFont, ImageDraw, ImageChops
import os
import math

def get_dynamic_font(dpi, height_in_inches=0.25, font_name="arial.ttf"):
    from matplotlib import font_manager
    font_path = font_manager.findfont(font_name)
    font_size_px = int(height_in_inches * dpi)
    try:
        font = ImageFont.truetype(font_path, font_size_px)
    except Exception as e:
        print("Failed to load truetype font:", e)
        font = ImageFont.load_default()
    return font

def resize_to_match_height(img, target_height):
    w, h = img.size
    new_width = int(w * target_height / h)
    return img.resize((new_width, target_height), Image.LANCZOS)

def combine_images(image_paths, output_path, columns=2, background_color='white',
                   margin=0, index_h=0.25, resize=False):
    '''
        image_paths
        output_path
        columns
        background_color
        margin
        index_h
    '''
    labels = ['(a)', '(b)', '(c)', '(d)', '(e)', '(f)', '(g)', '(h)', '(i)', '(j)']
    if not image_paths:
        raise ValueError("No images provided.")

    # -------------------------------
    # Pass 1: compute global bounding box
    # -------------------------------
    global_left, global_upper, global_right, global_lower = None, None, None, None
    for p in image_paths:
        img = Image.open(p).convert('RGB')
        bg = Image.new('RGB', img.size, background_color)
        diff = ImageChops.difference(img, bg)
        bbox = diff.getbbox()
        if bbox:
            left, upper, right, lower = bbox
            # Apply margin
            left = max(left - margin, 0)
            upper = max(upper - margin, 0)
            right = min(right + margin, img.width)
            lower = min(lower + margin, img.height)

            global_left   = left   if global_left is None else min(global_left, left)
            global_upper  = upper  if global_upper is None else min(global_upper, upper)
            global_right  = right  if global_right is None else max(global_right, right)
            global_lower  = lower  if global_lower is None else max(global_lower, lower)
        img.close()

    if global_left is None:  # No content found
        raise ValueError("No figure content detected in images.")

    # -------------------------------
    # Pass 2: crop all images with the global bbox
    # -------------------------------
    images = []
    first_img = None
    for i, p in enumerate(image_paths):
        img = Image.open(p).convert('RGB')
        cropped_img = img.crop((global_left, global_upper, global_right, global_lower))
        if i == 0:
            first_img = cropped_img
        elif resize:
            cropped_img = resize_to_match_height(cropped_img, first_img.height)
        images.append(cropped_img)
        img.close()

    # Ensure all images have the same DPI
    dpis = [img.info.get("dpi", (72, 72)) for img in images]
    if not all(dpi == dpis[0] for dpi in dpis):
        print("Warning: Images have different DPI. Using DPI of the first image.")

    dpi = dpis[0]

    # Get max width and height of all images
    widths, heights = zip(*(img.size for img in images))
    max_width = max(widths)
    max_height = max(heights)

    # Calculate rows
    rows = math.ceil(len(images) / columns)

    # Create new blank image
    combined_width = columns * max_width
    combined_height = rows * max_height
    combined_image = Image.new("RGB", (combined_width, combined_height), color=(255, 255, 255))

    # Get font
    font = get_dynamic_font(dpi[0], height_in_inches=index_h)

    # Paste images into the combined image
    for index, image in enumerate(images):
        row = index // columns
        col = index % columns
        x = col * max_width
        y = row * max_height
        combined_image.paste(image, (x, y))
        draw = ImageDraw.Draw(combined_image)
        draw.text((x + 10, y + 10), labels[index], font=font, fill=(0, 0, 0))

    # Final optional resize crop of the whole combined image
    if resize:
        bg = Image.new('RGB', combined_image.size, background_color)
        diff = ImageChops.difference(combined_image, bg)
        bbox = diff.getbbox()
        if bbox:
            left = max(bbox[0] - margin, 0)
            upper = max(bbox[1] - margin, 0)
            right = min(bbox[2] + margin, combined_image.width)
            lower = min(bbox[3] + margin, combined_image.height)
            combined_image = combined_image.crop((left, upper, right, lower))

    # Save the result with DPI
    combined_image.save(output_path, dpi=dpi)
    print(f"Saved combined image to {output_path} with DPI {dpi}")

# %%
nCols = 2
indexH = 0.2

# filetmp = '{figsdir}/{plotType}.{loopname}.{wvltag}.{timeRange}.png'
# figsdir = '/glade/work/swei/projects/mmm.pace_aod/plots/cycles/obs'
# filetmp = '{figsdir}/{obsname}/{plotType}.{loopname}.{wvltag}.{timeRange}.png'
# outfiletmp = '{savedir}/{plotType}.{set_type}.{wvltag}.{timeRange}.png'

figsdir = '/glade/work/swei/projects/mmm.pace_aod/plots/gridded'
filetmp = '{figsdir}/{plotType}.{loopname}.{timeRange}.png'
outfiletmp = '{savedir}/{plotType}.{set_type}.{timeRange}.png'
savedir = '/glade/work/swei/projects/mmm.pace_aod/plots/combined'
plotType = 'obs_mean'
set_dict = {
    'main': [
        'pace_aod',
        'modis_aqua_aod',
        'viirs_aod_dt_n20',
        'viirs_aod_db_n20',
        # 'pace_aod-modis_aqua_aod',
        # 'pace_aod-viirs_aod_dt_n20',
        # 'pace_aod-viirs_aod_db_n20',
        # 'merra2',
    ],
    'sup': [
        'pace_aod',
        'modis_terra_aod',
        'viirs_aod_dt_npp',
        'viirs_aod_db_npp',
        # 'pace_aod-modis_terra_aod',
        # 'pace_aod-viirs_aod_dt_npp',
        # 'pace_aod-viirs_aod_db_npp',
    ]
}
set_type = 'main'
wvltag = '550nm'
timeRange = '202411'
# timeRange = '2024110100_2024113018'
loop_list = set_dict[set_type]
margin = 60

outfile = outfiletmp.format(savedir=savedir, plotType=plotType, set_type=set_type, wvltag=wvltag, timeRange=timeRange)

# %%
image_paths = []
for loopname in loop_list:
    tmpfile = filetmp.format(figsdir=figsdir, loopname=loopname, plotType=plotType, wvltag=wvltag, timeRange=timeRange)
    if not os.path.exists(tmpfile):
        raise Exception(f'{tmpfile} does not exist')
    image_paths.append(tmpfile)
combine_images(image_paths, outfile, columns=nCols, margin=margin, index_h=indexH)
# Out:
# Saved combined image to /glade/work/swei/projects/mmm.pace_aod/plots/combined/obs_mean.main.202411.png with DPI (599.9988, 599.9988)

# %%
# Run with specified file list:
nCols = 2
indexH = 0.2
margin = 65
savedir = '/glade/work/swei/projects/mmm.pace_aod/plots.1/combined'
if not os.path.exists(savedir):
    os.makedirs(savedir)

# combined_type = 'wrfchem_vs_tempo_tropomi'
# combined_type = 'wrfchem_vs_pandora'
# combined_type = 'bias_crmse.wrfchem_vs_tempo_tropomi'
# combined_type = 'all.hist2d.main'
# combined_type = 'obs_vs_AERONETL15.hist2d.all'
# combined_type = 'wrfchem_vs_airnow'
combined_type = 'merra2_vs_aeronet'

dir_range_dict = {
    'all.hist2d.main': (
        '/glade/work/swei/projects/mmm.pace_aod/plots.1/stats',
        '2024110100_2024113018',
    ),
    'wrfchem_vs_pandora': (
        '/glade/work/swei/Git/JEDI-METplus/output/wrfchem_evaluate/plots/2dmap/pandora_no2_total-wxaq',
        '2024082419',
    ),
    'wrfchem_vs_tempo_tropomi': (
        '/glade/work/swei/Git/JEDI-METplus/output/wrfchem_evaluate/plots/2dmap',
        '2024082419',
    ),
    'bias_crmse.wrfchem_vs_tempo_tropomi': (
        '/glade/work/swei/Git/JEDI-METplus/output/wrfchem_evaluate/plots/timeseries',
        '2024082201_2024090100',
    ),
    'obs_vs_AERONETL15.hist2d.all': (
        '/glade/work/swei/projects/mmm.pace_aod/plots/stats/vs_AERONET_L1.5',
        '2024110100_2024113018',
    ),
    'wrfchem_vs_airnow': (
        '/glade/work/swei/projects/JEDI-ACE/output/wrfchem_evaluate/plots/2dmap/airnow-wxaq',
        '2024082201_2024090100',
    ),
    'merra2_vs_aeronet': (
        '/glade/work/swei/projects/mmm.pace_aod/plots/stats',
        '2024110100_2024113018',
    )
}

figdir, timeRange = dir_range_dict[combined_type]

outfile = f'{savedir}/{combined_type}.{timeRange}.png'
image_paths_dict = {
    'all.hist2d.main': [
        f"{figdir}/all.hist2d.pace_aod.550nm.2024110100_2024113018.png",
        f"{figdir}/all.hist2d.modis_aqua_aod.550nm.2024110100_2024113018.png",
        f"{figdir}/all.hist2d.viirs_aod_dt_n20.550nm.2024110100_2024113018.png",
        f"{figdir}/all.hist2d.viirs_aod_db_n20.550nm.2024110100_2024113018.png",
        f"{figdir}/all.hist2d.aeronet_l15_aod.500nm.2024110100_2024113018.png",
    ],
    'wrfchem_vs_pandora': [
        f"{figdir}/NewYork.ObsValue.nitrogendioxideTotal.f19.2024082419.png",
        f"{figdir}/Boston.ObsValue.nitrogendioxideTotal.f19.2024082419.png",
        f"{figdir}/Toronto.ObsValue.nitrogendioxideTotal.f19.2024082419.png",
        f"{figdir}/NewYork.hofx.nitrogendioxideTotal.f19.2024082419.png",
        f"{figdir}/Boston.hofx.nitrogendioxideTotal.f19.2024082419.png",
        f"{figdir}/Toronto.hofx.nitrogendioxideTotal.f19.2024082419.png",
    ],
    'bias_crmse.wrfchem_vs_tempo_tropomi': [
        f"{figdir}/bias.TROPOMI_TEMPO.2024082201_2024090100.png",
        # f"{figdir}/rmse.TROPOMI_TEMPO.2024082201_2024090100.png",
        f"{figdir}/crmse.TROPOMI_TEMPO.2024082201_2024090100.png"
    ],
    'wrfchem_vs_tempo_tropomi': [
        f"{figdir}/tropomi_s5p_no2_troposphere-wxaq/ObsValue_nitrogendioxideColumn.f19.2024082419.png",
        f"{figdir}/tropomi_s5p_no2_troposphere-wxaq/hofx_nitrogendioxideColumn.f19.2024082419.png",
        f"{figdir}/tempo_no2_tropo-wxaq/ObsValue_nitrogendioxideColumn.f19.2024082419.png",
        f"{figdir}/tempo_no2_tropo-wxaq/hofx_nitrogendioxideColumn.f19.2024082419.png",
    ],
    'obs_vs_AERONETL15.hist2d.all': [
        # f"{figdir}/obs_vs_AERONETL15.hist2d.pace_aod.2024110100_2024113018.png",
        f"{figdir}/obs_vs_AERONETL15.hist2d.modis_aqua_aod.2024110100_2024113018.png",
        f"{figdir}/obs_vs_AERONETL15.hist2d.viirs_aod_dt_n20.2024110100_2024113018.png",
        f"{figdir}/obs_vs_AERONETL15.hist2d.viirs_aod_db_n20.2024110100_2024113018.png",
        f"{figdir}/obs_vs_AERONETL15.hist2d.modis_terra_aod.2024110100_2024113018.png",
        f"{figdir}/obs_vs_AERONETL15.hist2d.viirs_aod_dt_npp.2024110100_2024113018.png",
        f"{figdir}/obs_vs_AERONETL15.hist2d.viirs_aod_db_npp.2024110100_2024113018.png",
    ],
    'wrfchem_vs_airnow': [
        f"{figdir}/bias.pm25.2024082200_2024083100.png",
        f"{figdir}/bias.ozone.2024082200_2024083100.png",
    ],
    'merra2_vs_aeronet': [
        f"{figdir}/AERONETL15_Bias.2024110100_2024113018.png",
        f"{figdir}/AERONETL15.2024110100_2024113018.png",
    ]
}
image_paths = image_paths_dict[combined_type]

combine_images(image_paths, outfile, columns=nCols, margin=margin, index_h=indexH, resize=True)
# Out:
# Saved combined image to /glade/work/swei/projects/mmm.pace_aod/plots.1/combined/merra2_vs_aeronet.2024110100_2024113018.png with DPI (599.9988, 599.9988)

# %%
# MPAS-DART output
nCols = 3
indexH = 0.2
margin = 60

exp_plotpath = '/glade/work/swei/projects/hydrosat/plots'
varname = 'precipw'
outpath = f'{exp_plotpath}/combined/{varname}'
plotcycle = 2024050900

outpng = f'{varname}.{plotcycle}.png'
outfile = f'{outpath}/{outpng}'

if not os.path.exists(outpath):
    os.makedirs(outpath)

image_paths = [
    f'{exp_plotpath}/base15km/{varname}/{varname}.{plotcycle}.png',
    f'{exp_plotpath}/naturalrun_3km/{varname}/{varname}.{plotcycle}.png',
    f'{exp_plotpath}/superobhyd15km/{varname}/{varname}.{plotcycle}.png',
]

combine_images(image_paths, outfile, columns=nCols, margin=margin, index_h=indexH, resize=False)
# Out:
# Saved combined image to /glade/work/swei/projects/hydrosat/plots/combined/precipw/precipw.2024050900.png with DPI (299.9994, 299.9994)
