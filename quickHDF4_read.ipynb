# %%
from pyhdf.HDF import *
from pyhdf.VS import *
from pyhdf.SD import SD, SDC
import numpy as np

# %%
def get_normalized_bit(value, bit_index):
    return (value >> bit_index) & 1

# %%
#infile = '/glade/derecho/scratch/swei/Dataset/input/obs/calipso/CAL_LID_L2_05kmAPro-Standard-V4-20.2019-07-22T07-49-21ZD.hdf'
infile = '/glade/work/swei/skylab/workdir/05a659/20241130T180000Z/obs_modis_aqua_aod/obs.modis_aqua_aod.20241130T180000Z.41'
# hdf = HDF(infile)
# vs = hdf.vstart()
# metaid = vs.find('metadata')
# vd = vs.attach(metaid)
# vd.setfields('Lidar_Data_Altitudes')
# alt = np.array(vd.read()[0][0])
# vd.detach()
# vs.end()

# %%
sd = SD(infile, SDC.READ)

# %%
sd.datasets()
# Out:
# {'Longitude': (('Cell_Along_Swath:mod04', 'Cell_Across_Swath:mod04'),
#   (203, 135),
#   5,
#   0),
#  'Latitude': (('Cell_Along_Swath:mod04', 'Cell_Across_Swath:mod04'),
#   (203, 135),
#   5,
#   1),
#  'Scan_Start_Time': (('Cell_Along_Swath:mod04', 'Cell_Across_Swath:mod04'),
#   (203, 135),
#   6,
#   2),
#  'Solar_Zenith': (('Cell_Along_Swath:mod04', 'Cell_Across_Swath:mod04'),
#   (203, 135),
#   22,
#   3),
#  'Solar_Azimuth': (('Cell_Along_Swath:mod04', 'Cell_Across_Swath:mod04'),
#   (203, 135),
#   22,
#   4),
#  'Sensor_Zenith': (('Cell_Along_Swath:mod04', 'Cell_Across_Swath:mod04'),
#   (203, 135),
#   22,
#   5),
#  'Sensor_Azimuth': (('Cell_Along_Swath:mod04', 'Cell_Across_Swath:mod04'),
#   (203, 135),
#   22,
#   6),
#  'Scattering_Angle': (('Cell_Along_Swath:mod04', 'Cell_Across_Swath:mod04'),
#   (203, 135),
#   22,
#   7),
#  'Land_sea_Flag': (('Cell_Along_Swath:mod04', 'Cell_Across_Swath:mod04'),
#   (203, 135),
#   22,
#   8),
#  'Aerosol_Cldmask_Land_Ocean': (('Cell_Along_Swath_500:mod04',
#    'Cell_Across_Swath_500:mod04'),
#   (4060, 2708),
#   22,
#   9),
#  'Cloud_Pixel_Distance_Land_Ocean': (('Cell_Along_Swath_500:mod04',
#    'Cell_Across_Swath_500:mod04'),
#   (4060, 2708),
#   22,
#   10),
#  'Land_Ocean_Quality_Flag': (('Cell_Along_Swath:mod04',
#    'Cell_Across_Swath:mod04'),
#   (203, 135),
#   22,
#   11),
#  'Optical_Depth_Land_And_Ocean': (('Cell_Along_Swath:mod04',
#    'Cell_Across_Swath:mod04'),
#   (203, 135),
#   22,
#   12),
#  'Image_Optical_Depth_Land_And_Ocean': (('Cell_Along_Swath:mod04',
#    'Cell_Across_Swath:mod04'),
#   (203, 135),
#   22,
#   13),
#  'Average_Cloud_Pixel_Distance_Land_Ocean': (('Cell_Along_Swath:mod04',
#    'Cell_Across_Swath:mod04'),
#   (203, 135),
#   22,
#   14),
#  'Aerosol_Type_Land': (('Cell_Along_Swath:mod04', 'Cell_Across_Swath:mod04'),
#   (203, 135),
#   22,
#   15),
#  'Fitting_Error_Land': (('Cell_Along_Swath:mod04', 'Cell_Across_Swath:mod04'),
#   (203, 135),
#   22,
#   16),
#  'Surface_Reflectance_Land': (('Solution_2_Land:mod04',
#    'Cell_Along_Swath:mod04',
#    'Cell_Across_Swath:mod04'),
#   (3, 203, 135),
#   22,
#   17),
#  'Corrected_Optical_Depth_Land': (('Solution_3_Land:mod04',
#    'Cell_Along_Swath:mod04',
#    'Cell_Across_Swath:mod04'),
#   (3, 203, 135),
#   22,
#   18),
#  'Corrected_Optical_Depth_Land_wav2p1': (('Cell_Along_Swath:mod04',
#    'Cell_Across_Swath:mod04'),
#   (203, 135),
#   22,
#   19),
#  'Optical_Depth_Ratio_Small_Land': (('Cell_Along_Swath:mod04',
#    'Cell_Across_Swath:mod04'),
#   (203, 135),
#   22,
#   20),
#  'Number_Pixels_Used_Land': (('MODIS_Band_AND_NPP_Extra:mod04',
#    'Cell_Along_Swath:mod04',
#    'Cell_Across_Swath:mod04'),
#   (10, 203, 135),
#   22,
#   21),
#  'Mean_Reflectance_Land': (('MODIS_Band_AND_NPP_Extra:mod04',
#    'Cell_Along_Swath:mod04',
#    'Cell_Across_Swath:mod04'),
#   (10, 203, 135),
#   22,
#   22),
#  'STD_Reflectance_Land': (('MODIS_Band_AND_NPP_Extra:mod04',
#    'Cell_Along_Swath:mod04',
#    'Cell_Across_Swath:mod04'),
#   (10, 203, 135),
#   22,
#   23),
#  'Mass_Concentration_Land': (('Cell_Along_Swath:mod04',
#    'Cell_Across_Swath:mod04'),
#   (203, 135),
#   5,
#   24),
#  'Aerosol_Cloud_Fraction_Land': (('Cell_Along_Swath:mod04',
#    'Cell_Across_Swath:mod04'),
#   (203, 135),
#   22,
#   25),
#  'Quality_Assurance_Land': (('Cell_Along_Swath:mod04',
#    'Cell_Across_Swath:mod04',
#    'QA_Byte_Land:mod04'),
#   (203, 135, 6),
#   20,
#   26),
#  'Solution_Index_Ocean_Small': (('Solution_Ocean:mod04',
#    'Cell_Along_Swath:mod04',
#    'Cell_Across_Swath:mod04'),
#   (2, 203, 135),
#   22,
#   27),
#  'Solution_Index_Ocean_Large': (('Solution_Ocean:mod04',
#    'Cell_Along_Swath:mod04',
#    'Cell_Across_Swath:mod04'),
#   (2, 203, 135),
#   22,
#   28),
#  'Effective_Optical_Depth_Best_Ocean': (('MODIS_Band_Ocean:mod04',
#    'Cell_Along_Swath:mod04',
#    'Cell_Across_Swath:mod04'),
#   (7, 203, 135),
#   22,
#   29),
#  'Effective_Optical_Depth_Average_Ocean': (('MODIS_Band_Ocean:mod04',
#    'Cell_Along_Swath:mod04',
#    'Cell_Across_Swath:mod04'),
#   (7, 203, 135),
#   22,
#   30),
#  'Optical_Depth_Small_Best_Ocean': (('MODIS_Band_Ocean:mod04',
#    'Cell_Along_Swath:mod04',
#    'Cell_Across_Swath:mod04'),
#   (7, 203, 135),
#   22,
#   31),
#  'Optical_Depth_Small_Average_Ocean': (('MODIS_Band_Ocean:mod04',
#    'Cell_Along_Swath:mod04',
#    'Cell_Across_Swath:mod04'),
#   (7, 203, 135),
#   22,
#   32),
#  'Optical_Depth_Large_Best_Ocean': (('MODIS_Band_Ocean:mod04',
#    'Cell_Along_Swath:mod04',
#    'Cell_Across_Swath:mod04'),
#   (7, 203, 135),
#   22,
#   33),
#  'Optical_Depth_Large_Average_Ocean': (('MODIS_Band_Ocean:mod04',
#    'Cell_Along_Swath:mod04',
#    'Cell_Across_Swath:mod04'),
#   (7, 203, 135),
#   22,
#   34),
#  'Mass_Concentration_Ocean': (('Solution_Ocean:mod04',
#    'Cell_Along_Swath:mod04',
#    'Cell_Across_Swath:mod04'),
#   (2, 203, 135),
#   5,
#   35),
#  'Aerosol_Cloud_Fraction_Ocean': (('Cell_Along_Swath:mod04',
#    'Cell_Across_Swath:mod04'),
#   (203, 135),
#   22,
#   36),
#  'Effective_Radius_Ocean': (('Solution_Ocean:mod04',
#    'Cell_Along_Swath:mod04',
#    'Cell_Across_Swath:mod04'),
#   (2, 203, 135),
#   22,
#   37),
#  'PSML003_Ocean': (('Solution_Ocean:mod04',
#    'Cell_Along_Swath:mod04',
#    'Cell_Across_Swath:mod04'),
#   (2, 203, 135),
#   5,
#   38),
#  'Asymmetry_Factor_Best_Ocean': (('MODIS_Band_Ocean:mod04',
#    'Cell_Along_Swath:mod04',
#    'Cell_Across_Swath:mod04'),
#   (7, 203, 135),
#   22,
#   39),
#  'Asymmetry_Factor_Average_Ocean': (('MODIS_Band_Ocean:mod04',
#    'Cell_Along_Swath:mod04',
#    'Cell_Across_Swath:mod04'),
#   (7, 203, 135),
#   22,
#   40),
#  'Backscattering_Ratio_Best_Ocean': (('MODIS_Band_Ocean:mod04',
#    'Cell_Along_Swath:mod04',
#    'Cell_Across_Swath:mod04'),
#   (7, 203, 135),
#   22,
#   41),
#  'Backscattering_Ratio_Average_Ocean': (('MODIS_Band_Ocean:mod04',
#    'Cell_Along_Swath:mod04',
#    'Cell_Across_Swath:mod04'),
#   (7, 203, 135),
#   22,
#   42),
#  'Angstrom_Exponent_1_Ocean': (('Cell_Along_Swath:mod04',
#    'Cell_Across_Swath:mod04'),
#   (203, 135),
#   22,
#   43),
#  'Angstrom_Exponent_2_Ocean': (('Cell_Along_Swath:mod04',
#    'Cell_Across_Swath:mod04'),
#   (203, 135),
#   22,
#   44),
#  'Least_Squares_Error_Ocean': (('Solution_Ocean:mod04',
#    'Cell_Along_Swath:mod04',
#    'Cell_Across_Swath:mod04'),
#   (2, 203, 135),
#   22,
#   45),
#  'Optical_Depth_Ratio_Small_Ocean_0.55micron': (('Cell_Along_Swath:mod04',
#    'Cell_Across_Swath:mod04'),
#   (203, 135),
#   22,
#   46),
#  'Optical_Depth_by_models_ocean': (('Solution_Index:mod04',
#    'Cell_Along_Swath:mod04',
#    'Cell_Across_Swath:mod04'),
#   (9, 203, 135),
#   22,
#   47),
#  'Number_Pixels_Used_Ocean': (('MODIS_Band_AND_NPP_Extra:mod04',
#    'Cell_Along_Swath:mod04',
#    'Cell_Across_Swath:mod04'),
#   (10, 203, 135),
#   22,
#   48),
#  'Mean_Reflectance_Ocean': (('MODIS_Band_AND_NPP_Extra:mod04',
#    'Cell_Along_Swath:mod04',
#    'Cell_Across_Swath:mod04'),
#   (10, 203, 135),
#   22,
#   49),
#  'STD_Reflectance_Ocean': (('MODIS_Band_AND_NPP_Extra:mod04',
#    'Cell_Along_Swath:mod04',
#    'Cell_Across_Swath:mod04'),
#   (10, 203, 135),
#   22,
#   50),
#  'Quality_Assurance_Ocean': (('Cell_Along_Swath:mod04',
#    'Cell_Across_Swath:mod04',
#    'QA_Byte_Ocean:mod04'),
#   (203, 135, 5),
#   20,
#   51),
#  'Deep_Blue_Aerosol_Optical_Depth_550_Land': (('Cell_Along_Swath:mod04',
#    'Cell_Across_Swath:mod04'),
#   (203, 135),
#   22,
#   52),
#  'Deep_Blue_Spectral_Aerosol_Optical_Depth_Land': (('Num_DeepBlue_Wavelengths:mod04',
#    'Cell_Along_Swath:mod04',
#    'Cell_Across_Swath:mod04'),
#   (3, 203, 135),
#   22,
#   53),
#  'Deep_Blue_Angstrom_Exponent_Land': (('Cell_Along_Swath:mod04',
#    'Cell_Across_Swath:mod04'),
#   (203, 135),
#   22,
#   54),
#  'Deep_Blue_Spectral_Single_Scattering_Albedo_Land': (('Num_DeepBlue_Wavelengths:mod04',
#    'Cell_Along_Swath:mod04',
#    'Cell_Across_Swath:mod04'),
#   (3, 203, 135),
#   22,
#   55),
#  'Deep_Blue_Spectral_Surface_Reflectance_Land': (('Num_DeepBlue_Wavelengths:mod04',
#    'Cell_Along_Swath:mod04',
#    'Cell_Across_Swath:mod04'),
#   (3, 203, 135),
#   22,
#   56),
#  'Deep_Blue_Spectral_TOA_Reflectance_Land': (('Num_DeepBlue_Wavelengths:mod04',
#    'Cell_Along_Swath:mod04',
#    'Cell_Across_Swath:mod04'),
#   (3, 203, 135),
#   22,
#   57),
#  'Deep_Blue_Number_Pixels_Used_550_Land': (('Cell_Along_Swath:mod04',
#    'Cell_Across_Swath:mod04'),
#   (203, 135),
#   22,
#   58),
#  'Deep_Blue_Aerosol_Optical_Depth_550_Land_STD': (('Cell_Along_Swath:mod04',
#    'Cell_Across_Swath:mod04'),
#   (203, 135),
#   22,
#   59),
#  'Deep_Blue_Cloud_Fraction_Land': (('Cell_Along_Swath:mod04',
#    'Cell_Across_Swath:mod04'),
#   (203, 135),
#   22,
#   60),
#  'Deep_Blue_Aerosol_Optical_Depth_550_Land_QA_Flag': (('Cell_Along_Swath:mod04',
#    'Cell_Across_Swath:mod04'),
#   (203, 135),
#   22,
#   61),
#  'Deep_Blue_Algorithm_Flag_Land': (('Cell_Along_Swath:mod04',
#    'Cell_Across_Swath:mod04'),
#   (203, 135),
#   22,
#   62),
#  'Deep_Blue_Aerosol_Optical_Depth_550_Land_Best_Estimate': (('Cell_Along_Swath:mod04',
#    'Cell_Across_Swath:mod04'),
#   (203, 135),
#   22,
#   63),
#  'Deep_Blue_Aerosol_Optical_Depth_550_Land_Estimated_Uncertainty': (('Cell_Along_Swath:mod04',
#    'Cell_Across_Swath:mod04'),
#   (203, 135),
#   22,
#   64),
#  'AOD_550_Dark_Target_Deep_Blue_Combined': (('Cell_Along_Swath:mod04',
#    'Cell_Across_Swath:mod04'),
#   (203, 135),
#   22,
#   65),
#  'AOD_550_Dark_Target_Deep_Blue_Combined_QA_Flag': (('Cell_Along_Swath:mod04',
#    'Cell_Across_Swath:mod04'),
#   (203, 135),
#   22,
#   66),
#  'AOD_550_Dark_Target_Deep_Blue_Combined_Algorithm_Flag': (('Cell_Along_Swath:mod04',
#    'Cell_Across_Swath:mod04'),
#   (203, 135),
#   22,
#   67),
#  'Glint_Angle': (('Cell_Along_Swath:mod04', 'Cell_Across_Swath:mod04'),
#   (203, 135),
#   22,
#   68),
#  'Wind_Speed_Ncep_Ocean': (('Cell_Along_Swath:mod04',
#    'Cell_Across_Swath:mod04'),
#   (203, 135),
#   22,
#   69),
#  'Topographic_Altitude_Land': (('Cell_Along_Swath:mod04',
#    'Cell_Across_Swath:mod04'),
#   (203, 135),
#   22,
#   70),
#  'Effective_Optical_Depth_0p55um_Ocean': (('Cell_Along_Swath:mod04',
#    'Cell_Across_Swath:mod04'),
#   (203, 135),
#   22,
#   71)}
